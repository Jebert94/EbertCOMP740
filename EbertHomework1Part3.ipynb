# %% [markdown]
# Homework 1
# Josh Ebert

# %%
import pandas as pd 
header = ["variance", "skew", "curtsies", "entropy", "classes"]
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00267/data_banknote_authentication.txt"
df = pd.read_csv(url, names=header)

# %%
df
# Out:
#       variance      skew  curtsies  entropy  classes
# 0      3.62160   8.66610   -2.8073 -0.44699        0
# 1      4.54590   8.16740   -2.4586 -1.46210        0
# 2      3.86600  -2.63830    1.9242  0.10645        0
# 3      3.45660   9.52280   -4.0112 -3.59440        0
# 4      0.32924  -4.45520    4.5718 -0.98880        0
# ...        ...       ...       ...      ...      ...
# 1367   0.40614   1.34920   -1.4501 -0.55949        1
# 1368  -1.38870  -4.87730    6.4774  0.34179        1
# 1369  -3.75030 -13.45860   17.5932 -2.77710        1
# 1370  -3.56370  -8.38270   12.3930 -1.28230        1
# 1371  -2.54190  -0.65804    2.6842  1.19520        1
#
# [1372 rows x 5 columns]

# %% [markdown]
# Here is the descriptive analysis!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   variance  1372 non-null   float64
#  1   skew      1372 non-null   float64
#  2   curtsies  1372 non-null   float64
#  3   entropy   1372 non-null   float64
#  4   classes   1372 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 53.7 KB

# %% [markdown]
# Here is where I check if the data contains any null values!

# %%
df.isnull().sum()
# Out:
# variance    0
# skew        0
# curtsies    0
# entropy     0
# classes     0
# dtype: int64

# %% [markdown]
# Here is where I visualize the data!

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'variance'}>,
#         <AxesSubplot:title={'center':'skew'}>],
#        [<AxesSubplot:title={'center':'curtsies'}>,
#         <AxesSubplot:title={'center':'entropy'}>],
#        [<AxesSubplot:title={'center':'classes'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# Here is where I prepare the train set and the test set!
# Assigns all of the data besides the classes column to X(input data)
# Assigns the classes column(output data)

# %%
X = df.drop(['classes'], axis=1)
y = df['classes']

# %% [markdown]
# splits arrays or matrices into random tran and test subests with a test size of 40% of the data and classified by classes

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, stratify=y)

# %% [markdown]
# Uses perception classificaiton algorithm.Has a maximum of 40 passes,a constant updata of .1 and a random state set to true.

# %%
from sklearn.linear_model import Perceptron

ppn = Perceptron(max_iter=40, eta0=0.1, random_state=1)
ppn.fit(X_train, y_train)
# Out:
# Perceptron(eta0=0.1, max_iter=40, random_state=1)

# %% [markdown]
# Can now make predicitons over the trained model

# %%
y_pred = ppn.predict(X_test)

# %% [markdown]
# Runs the test

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.9817850637522769

# %%
y_test
# Out:
# 126     0
# 7       0
# 1082    1
# 188     0
# 719     0
#        ..
# 1150    1
# 876     1
# 642     0
# 348     0
# 297     0
# Name: classes, Length: 549, dtype: int64
